# %%
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
config_path = Path('../dash_config')

# %%
from oa_cohorts.query.query_plan import QueryPlan, SubqueryNode
from omop_constructs.semantics import registry, registry_engine
from oa_cohorts.query.subquery import Subquery, SQLQuery
from sqlalchemy.orm import sessionmaker
from orm_loader.helpers import Base  

Base.metadata.create_all(registry_engine)
Session = sessionmaker(bind=registry_engine, future=True)

session = Session()
# Out:
# /Users/z3061723/Documents/CODE/OA_cohorts-1/.venv/lib/python3.13/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
sq = session.get(Subquery, 1)
QueryPlan(root=SubqueryNode(subquery=sq), title_text="Debug: Subquery")
# Out:
# <style>/* =========================
#    Render Blocks (Cards)
#    ========================= */
#
# .render-block {
#   border: 1px solid #aaa;
#   border-radius: 6px;
#   padding: 8px 12px;
#   margin: 10px 0 12px;
#   background: #fafafa;
#   max-width: 100%;
#   box-shadow: 0 1px 2px rgba(0,0,0,0.05);
# }
#
# .render-block > .title,
# .render-block .title {
#   font-weight: 700;
#   font-size: 1.05em;
#   margin-bottom: 6px;
#   color: #1f2937;
# }
#
# /* Nested blocks = tree structure */
# .render-block .render-block {
#   margin-left: 12px;
#   border-left: 3px solid #c7d2fe;
#   background: #f9fafb;
# }
#
# .render-block .render-block .render-block {
#   border-left-color: #a5b4fc;
# }
#
# /* Type-specific accents */
# .render-block.measure { border-color: #6366f1; }    /* indigo */
# .render-block.subquery { border-color: #059669; }   /* emerald */
# .render-block.queryrule { border-color: #f59e0b; }  /* amber */
#
#
# /* =========================
#    Meta Table (Headers)
# ...
